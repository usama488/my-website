# %% [markdown]
# <a href="https://colab.research.google.com/github/usama488/my-website/blob/main/Pharmacy_Login.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💊 **Pharmacy Login – Secure Access to Medical Management**

# %% [markdown]
# # Welcome to **Pharmacy Login**, a secure portal designed for pharmacists, staff, and administrators to manage pharmacy operations efficiently. This system ensures authorized access to essential features such as medicine inventory, prescription records, sales, and billing.
#
# # With a user-friendly interface and strong security measures, users can seamlessly log in to monitor stock levels, manage prescriptions, and ensure safe and accurate dispensing of medicines.
#
# ---
#
# # 🔐 **Ensuring secure, efficient, and reliable pharmacy management access.**

# %% [markdown]
# # https://raspy-frost-0a00.usamabinali132.workers.dev/
