# %% [markdown]
# <a href="https://colab.research.google.com/github/usama488/my-website/blob/main/Garage_Login.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔧 **Garage Login – Secure Access to Service Management**

# %% [markdown]
# # Welcome to **Garage Login**, a secure portal designed for mechanics, staff, and administrators to manage garage operations efficiently. This system ensures authorized access to essential features such as vehicle service records, customer details, job tracking, and billing.
#
# # With a user-friendly interface and strong security measures, users can seamlessly log in to monitor ongoing repairs, manage service history, and deliver reliable automotive services.
#
# ---
#
# # 🔐 **Ensuring secure and efficient access to garage management operations.**

# %% [markdown]
# # https://sweet-resonance-13c1.usamabinali132.workers.dev/
